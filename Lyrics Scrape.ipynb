# %% [markdown]
# Bryan Flores <br>
# ADS-509 <br>
# Assignment 1.1 <br>
# January 15, 2024

# %% [markdown]
# # ADS 509 Module 1: APIs and Web Scraping
#
# This notebook has two parts. In the first part, you will scrape lyrics from AZLyrics.com. In the second part, you'll run code that verifies the completeness of your data pull.
#
# For this assignment you have chosen two musical artists who have at least 20 songs with lyrics on AZLyrics.com. We start with pulling some information and analyzing them.

# %% [markdown]
# ## General Assignment Instructions
#
# These instructions are included in every assignment, to remind you of the coding standards for the class. Feel free to delete this cell after reading it.
#
# One sign of mature code is conforming to a style guide. We recommend the [Google Python Style Guide](https://google.github.io/styleguide/pyguide.html). If you use a different style guide, please include a cell with a link.
#
# Your code should be relatively easy-to-read, sensibly commented, and clean. Writing code is a messy process, so please be sure to edit your final submission. Remove any cells that are not needed or parts of cells that contain unnecessary code. Remove inessential `import` statements and make sure that all such statements are moved into the designated cell.
#
# Make use of non-code cells for written commentary. These cells should be grammatical and clearly written. In some of these cells you will have questions to answer. The questions will be marked by a "Q:" and will have a corresponding "A:" spot for you. *Make sure to answer every question marked with a `Q:` for full credit.*

# %% [markdown]
# # Importing Libraries

# %%
import os
import datetime
import re

# for the lyrics scrape section
import requests
import time
from bs4 import BeautifulSoup
from collections import defaultdict, Counter
import random

# %%
# Use this cell for any import statements you add

# %% [markdown]
# ---
#
# # Lyrics Scrape
#
# This section asks you to pull data by scraping www.AZLyrics.com. In the notebooks where you do that work you are asked to store the data in specific ways.

# %%
artists = {'badbunny':"https://www.azlyrics.com/b/badbunny.html",
           'farruko':"https://www.azlyrics.com/f/farruko.html"} 
# we'll use this dictionary to hold both the artist name and the link on AZlyrics

# %% [markdown]
# ## A Note on Rate Limiting
#
# The lyrics site, www.azlyrics.com, does not have an explicit maximum on number of requests in any one time, but in our testing it appears that too many requests in too short a time will cause the site to stop returning lyrics pages. (Entertainingly, the page that gets returned seems to only have the song title to [a Tom Jones song](https://www.azlyrics.com/lyrics/tomjones/itsnotunusual.html).)
#
# Whenever you call `requests.get` to retrieve a page, put a `time.sleep(5 + 10*random.random())` on the next line. This will help you not to get blocked. If you _do_ get blocked, which you can identify if the returned pages are not correct, just request a lyrics page through your browser. You'll be asked to perform a CAPTCHA and then your requests should start working again.
#
# ## Part 1: Finding Links to Songs Lyrics
#
# That general artist page has a list of all songs for that artist with links to the individual song pages.
#
# Q: Take a look at the `robots.txt` page on www.azlyrics.com. (You can read more about these pages [here](https://developers.google.com/search/docs/advanced/robots/intro).) Is the scraping we are about to do allowed or disallowed by this page? How do you know?
#
# A: <!-- Delete this comment and put your answer here. -->

# %%
# Let's set up a dictionary of lists to hold our links
lyrics_pages = defaultdict(list)

for artist, artist_page in artists.items() :
    # request the page and sleep
    r = requests.get(artist_page)
    time.sleep(5 + 10*random.random())

    # now extract the links to lyrics pages from this page
    # store the links `lyrics_pages` where the key is the artist and the
    # value is a list of links. 
    if r.status_code == 200:
        soup = BeautifulSoup(r.text,"html.parser")

        # Get lyrics pages and remove songs artist is not the lead singer
        for page_link in soup.find_all('a',href=re.compile(f"/lyrics/{artist}")):
            lyrics_pages[artist].append(page_link.attrs['href'])

# %%
# Validate lyrics pages to ensure no songs artist was only featured on
lyrics_pages
# Out:
# defaultdict(list,
#             {'badbunny': ['/lyrics/badbunny/nibiennimal.html',
#               '/lyrics/badbunny/200mph.html',
#               '/lyrics/badbunny/quinteres.html',
#               '/lyrics/badbunny/caro.html',
#               '/lyrics/badbunny/tenemosquehablar.html',
#               '/lyrics/badbunny/otranocheenmiami.html',
#               '/lyrics/badbunny/serbichote.html',
#               '/lyrics/badbunny/siestuvisemosjuntos.html',
#               '/lyrics/badbunny/solodemi.html',
#               '/lyrics/badbunny/cuandoperriabas.html',
#               '/lyrics/badbunny/laromana.html',
#               '/lyrics/badbunny/comoantes.html',
#               '/lyrics/badbunny/rlndt.html',
#               '/lyrics/badbunny/estamosbien.html',
#               '/lyrics/badbunny/mia708486.html',
#               '/lyrics/badbunny/siveoatumama.html',
#               '/lyrics/badbunny/ladificil.html',
#               '/lyrics/badbunny/peroyano.html',
#               '/lyrics/badbunny/lasanta.html',
#               '/lyrics/badbunny/yoperreosola.html',
#               '/lyrics/badbunny/bichiyal.html',
#               '/lyrics/badbunny/solia.html',
#               '/lyrics/badbunny/lazona.html',
#               '/lyrics/badbunny/quemalo.html',
#               '/lyrics/badbunny/vete.html',
#               '/lyrics/badbunny/ignorantes.html',
#               '/lyrics/badbunny/atumerced.html',
#               '/lyrics/badbunny/unavez.html',
#               '/lyrics/badbunny/safaera.html',
#               '/lyrics/badbunny/258.html',
#               '/lyrics/badbunny/estacabronseryo.html',
#               '/lyrics/badbunny/puestopaguerrial.html',
#               '/lyrics/badbunny/pfknr.html',
#               '/lyrics/badbunny/hablamosmanana.html',
#               '/lyrics/badbunny/3.html',
#               '/lyrics/badbunny/siellasale.html',
#               '/lyrics/badbunny/masdeunacita.html',
#               '/lyrics/badbunny/byemefui.html',
#               '/lyrics/badbunny/cancionconyandel.html',
#               '/lyrics/badbunny/paromperla.html',
#               '/lyrics/badbunny/badconnicky.html',
#               '/lyrics/badbunny/bendiciones.html',
#               '/lyrics/badbunny/comosesienteremix.html',
#               '/lyrics/badbunny/roncafreestyle.html',
#               '/lyrics/badbunny/encasita.html',
#               '/lyrics/badbunny/elmundoesmio.html',
#               '/lyrics/badbunny/temudaste.html',
#               '/lyrics/badbunny/hoycobre.html',
#               '/lyrics/badbunny/malditapobreza.html',
#               '/lyrics/badbunny/lanochedeanoche.html',
#               '/lyrics/badbunny/tedeseolomejor.html',
#               '/lyrics/badbunny/yovistoasi.html',
#               '/lyrics/badbunny/haciendoquemeamas.html',
#               '/lyrics/badbunny/bookert.html',
#               '/lyrics/badbunny/ladroga.html',
#               '/lyrics/badbunny/dakiti.html',
#               '/lyrics/badbunny/trellas.html',
#               '/lyrics/badbunny/sorrypapi.html',
#               '/lyrics/badbunny/120.html',
#               '/lyrics/badbunny/antesqueseacabe.html',
#               '/lyrics/badbunny/cantaresdenavidad.html',
#               '/lyrics/badbunny/moscowmule.html',
#               '/lyrics/badbunny/despuesdelaplaya.html',
#               '/lyrics/badbunny/meportobonito.html',
#               '/lyrics/badbunny/titimepregunto.html',
#               '/lyrics/badbunny/unratito.html',
#               '/lyrics/badbunny/yonosoyceloso.html',
#               '/lyrics/badbunny/tarot.html',
#               '/lyrics/badbunny/neverita.html',
#               '/lyrics/badbunny/lacorriente.html',
#               '/lyrics/badbunny/efecto.html',
#               '/lyrics/badbunny/party.html',
#               '/lyrics/badbunny/aguacero.html',
#               '/lyrics/badbunny/ensenameabailar.html',
#               '/lyrics/badbunny/ojitoslindos.html',
#               '/lyrics/badbunny/dosmil16.html',
#               '/lyrics/badbunny/elapagon.html',
#               '/lyrics/badbunny/otroatardecer.html',
#               '/lyrics/badbunny/uncoco.html',
#               '/lyrics/badbunny/andrea.html',
#               '/lyrics/badbunny/mefuidevacaciones.html',
#               '/lyrics/badbunny/unveranosinti.html',
#               '/lyrics/badbunny/agosto.html',
#               '/lyrics/badbunny/callaita.html',
#               '/lyrics/badbunny/nadiesabe.html',
#               '/lyrics/badbunny/monaco.html',
#               '/lyrics/badbunny/fina.html',
#               '/lyrics/badbunny/hibiki.html',
#               '/lyrics/badbunny/mroctober.html',
#               '/lyrics/badbunny/cybertruck.html',
#               '/lyrics/badbunny/vou787.html',
#               '/lyrics/badbunny/seda.html',
#               '/lyrics/badbunny/graciaspornada.html',
#               '/lyrics/badbunny/telefononuevo.html',
#               '/lyrics/badbunny/babynueva.html',
#               '/lyrics/badbunny/mercedescarota.html',
#               '/lyrics/badbunny/lospits.html',
#               '/lyrics/badbunny/vuelvecandyb.html',
#               '/lyrics/badbunny/baticano.html',
#               '/lyrics/badbunny/nomequierocasar.html',
#               '/lyrics/badbunny/whereshegoes.html',
#               '/lyrics/badbunny/thunderylightning.html',
#               '/lyrics/badbunny/perronegro.html',
#               '/lyrics/badbunny/europa.html',
#               '/lyrics/badbunny/achopr.html',
#               '/lyrics/badbunny/unpreview.html',
#               '/lyrics/badbunny/100millones.html',
#               '/lyrics/badbunny/6rings.html',
#               '/lyrics/badbunny/amantesdeunanoche.html',
#               '/lyrics/badbunny/amigosyenemigosremix.html',
#               '/lyrics/badbunny/amorfoda.html',
#               '/lyrics/badbunny/blockia.html',
#               '/lyrics/badbunny/caile.html',
#               '/lyrics/badbunny/chambea.html',
#               '/lyrics/badbunny/compositordelano.html',
#               '/lyrics/badbunny/crecia.html',
#               '/lyrics/badbunny/demuseo.html',
#               '/lyrics/badbunny/demagagegigogu.html',
#               '/lyrics/badbunny/demoniabaila.html',
#               '/lyrics/badbunny/desdeelcorazn.html',
#               '/lyrics/badbunny/diles.html',
#               '/lyrics/badbunny/dilesremix.html',
#               '/lyrics/badbunny/dimesiteacuerdas.html',
#               '/lyrics/badbunny/enloquefreestyle.html',
#               '/lyrics/badbunny/estamosarriba.html',
#               '/lyrics/badbunny/flor.html',
#               '/lyrics/badbunny/giveitup.html',
#               '/lyrics/badbunny/hoy.html',
#               '/lyrics/badbunny/latshirtdebiggie.html',
#               '/lyrics/badbunny/lean.html',
#               '/lyrics/badbunny/losientobb.html',
#               '/lyrics/badbunny/mellueven.html',
#               '/lyrics/badbunny/mellueven2.html',
#               '/lyrics/badbunny/mellueven30.html',
#               '/lyrics/badbunny/memata.html',
#               '/lyrics/badbunny/mipuertorico.html',
#               '/lyrics/badbunny/mia.html',
#               '/lyrics/badbunny/miadomdabombremix.html',
#               '/lyrics/badbunny/mia20.html',
#               '/lyrics/badbunny/netflixxx.html',
#               '/lyrics/badbunny/notehagas.html',
#               '/lyrics/badbunny/otravez.html',
#               '/lyrics/badbunny/pati.html',
#               '/lyrics/badbunny/paquelederemix.html',
#               '/lyrics/badbunny/prayer.html',
#               '/lyrics/badbunny/prohibido.html',
#               '/lyrics/badbunny/salimosabuscarte.html',
#               '/lyrics/badbunny/sensualidad.html',
#               '/lyrics/badbunny/solita.html',
#               '/lyrics/badbunny/solteraremix.html',
#               '/lyrics/badbunny/soyeldiabloremix.html',
#               '/lyrics/badbunny/soypeor.html',
#               '/lyrics/badbunny/soypeorremix.html',
#               '/lyrics/badbunny/subimosderango.html',
#               '/lyrics/badbunny/tedescuid.html',
#               '/lyrics/badbunny/teguste.html',
#               '/lyrics/badbunny/telometoyo.html',
#               '/lyrics/badbunny/trepate.html',
#               '/lyrics/badbunny/nometescabra.html',
#               '/lyrics/badbunny/tunometescabraremix.html',
#               '/lyrics/badbunny/unratitomas.html',
#               '/lyrics/badbunny/vamospalacalle.html',
#               '/lyrics/badbunny/yoperreosolaremix.html',
#               '/lyrics/badbunny/yonaguni.html',
#               '/lyrics/badbunny/cualestuplan.html'],
#              'farruko': ['/lyrics/farruko/intro.html',
#               '/lyrics/farruko/nenafichu.html',
#               '/lyrics/farruko/ulala.html',
#               '/lyrics/farruko/ellanoesfcil.html',
#               '/lyrics/farruko/casadeplaya.html',
#               '/lyrics/farruko/pormiedoalamor.html',
#               '/lyrics/farruko/webcam.html',
#               '/lyrics/farruko/escuelasuperior.html',
#               '/lyrics/farruko/gettogether.html',
#               '/lyrics/farruko/muchachitabonita.html',
#               '/lyrics/farruko/traimeatuamiga.html',
#               '/lyrics/farruko/suhijamegusta.html',
#               '/lyrics/farruko/chuleraenpote.html',
#               '/lyrics/farruko/teirabuscar.html',
#               '/lyrics/farruko/titerito.html',
#               '/lyrics/farruko/dimequehago.html',
#               '/lyrics/farruko/pikete.html',
#               '/lyrics/farruko/feeltherhythm.html',
#               '/lyrics/farruko/elnico.html',
#               '/lyrics/farruko/nopierdas.html',
#               '/lyrics/farruko/buenavibra.html',
#               '/lyrics/farruko/vaaserabuela.html',
#               '/lyrics/farruko/eshora.html',
#               '/lyrics/farruko/vaatoa.html',
#               '/lyrics/farruko/sitepegocuerno.html',
#               '/lyrics/farruko/holabeba.html',
#               '/lyrics/farruko/voya100.html',
#               '/lyrics/farruko/bootybooty.html',
#               '/lyrics/farruko/besastanbien.html',
#               '/lyrics/farruko/mividanovaacambiar.html',
#               '/lyrics/farruko/foreveralone.html',
#               '/lyrics/farruko/noesunagial.html',
#               '/lyrics/farruko/unanena.html',
#               '/lyrics/farruko/hacerteelamor.html',
#               '/lyrics/farruko/rapapapam.html',
#               '/lyrics/farruko/excusas.html',
#               '/lyrics/farruko/tiempos.html',
#               '/lyrics/farruko/humildedecorazn.html',
#               '/lyrics/farruko/salgointro.html',
#               '/lyrics/farruko/recordarte.html',
#               '/lyrics/farruko/lejosdeaqui.html',
#               '/lyrics/farruko/estaspami.html',
#               '/lyrics/farruko/padarle.html',
#               '/lyrics/farruko/menor.html',
#               '/lyrics/farruko/miroelreloj.html',
#               '/lyrics/farruko/sinotetengo.html',
#               '/lyrics/farruko/nosoy.html',
#               '/lyrics/farruko/noquieresaber.html',
#               '/lyrics/farruko/interesada.html',
#               '/lyrics/farruko/bebeconmigo.html',
#               '/lyrics/farruko/profugo.html',
#               '/lyrics/farruko/passionwhine.html',
#               '/lyrics/farruko/asicreci.html',
#               '/lyrics/farruko/passionwhineremix.html',
#               '/lyrics/farruko/lanuevagerencia.html',
#               '/lyrics/farruko/visionary.html',
#               '/lyrics/farruko/fantasy.html',
#               '/lyrics/farruko/obsesionado.html',
#               '/lyrics/farruko/intimidad.html',
#               '/lyrics/farruko/hmb.html',
#               '/lyrics/farruko/papichamp.html',
#               '/lyrics/farruko/backtothefuture.html',
#               '/lyrics/farruko/chillax.html',
#               '/lyrics/farruko/neverletyougo.html',
#               '/lyrics/farruko/illusion.html',
#               '/lyrics/farruko/tevaadoler.html',
#               '/lyrics/farruko/power.html',
#               '/lyrics/farruko/sunset.html',
#               '/lyrics/farruko/angels.html',
#               '/lyrics/farruko/trapxficante.html',
#               '/lyrics/farruko/llgale.html',
#               '/lyrics/farruko/krippykush.html',
#               '/lyrics/farruko/explcale.html',
#               '/lyrics/farruko/noconfo.html',
#               '/lyrics/farruko/tevasconmigo.html',
#               '/lyrics/farruko/lefaltelrespetoaldinero.html',
#               '/lyrics/farruko/amaneci.html',
#               '/lyrics/farruko/chchch.html',
#               '/lyrics/farruko/paraac.html',
#               '/lyrics/farruko/mp5.html',
#               '/lyrics/farruko/spectrum.html',
#               '/lyrics/farruko/llamabeb.html',
#               '/lyrics/farruko/oscuridad.html',
#               '/lyrics/farruko/lunesviernes.html',
#               '/lyrics/farruko/sultatet.html',
#               '/lyrics/farruko/yeahbaby.html',
#               '/lyrics/farruko/kilokilo.html',
#               '/lyrics/farruko/mecans.html',
#               '/lyrics/farruko/miformadeser.html',
#               '/lyrics/farruko/dontletgo.html',
#               '/lyrics/farruko/lacartera.html',
#               '/lyrics/farruko/gangaxtrip.html',
#               '/lyrics/farruko/borinquenbella.html',
#               '/lyrics/farruko/prtatemal.html',
#               '/lyrics/farruko/playa.html',
#               '/lyrics/farruko/delincuente.html',
#               '/lyrics/farruko/sorpresa.html',
#               '/lyrics/farruko/tensin.html',
#               '/lyrics/farruko/resort.html',
#               '/lyrics/farruko/roatn.html',
#               '/lyrics/farruko/cartier.html',
#               '/lyrics/farruko/qudate.html',
#               '/lyrics/farruko/muchohumo.html',
#               '/lyrics/farruko/daledembow.html',
#               '/lyrics/farruko/deidad.html',
#               '/lyrics/farruko/rompeelsuelo.html',
#               '/lyrics/farruko/coolantremix.html',
#               '/lyrics/farruko/inolvidable.html',
#               '/lyrics/farruko/nadie.html',
#               '/lyrics/farruko/calmaremix.html',
#               '/lyrics/farruko/vuelvoanacer.html',
#               '/lyrics/farruko/quehaydemalo.html',
#               '/lyrics/farruko/minena.html',
#               '/lyrics/farruko/tesueltoelpelo.html',
#               '/lyrics/farruko/sensaciondelbloque.html',
#               '/lyrics/farruko/unalagrima.html',
#               '/lyrics/farruko/metrancaron.html',
#               '/lyrics/farruko/pastoypelea.html',
#               '/lyrics/farruko/youdontloveme.html',
#               '/lyrics/farruko/asignaturapendiente.html',
#               '/lyrics/farruko/ki.html',
#               '/lyrics/farruko/latoxica.html',
#               '/lyrics/farruko/pepas.html',
#               '/lyrics/farruko/gps.html',
#               '/lyrics/farruko/flove.html',
#               '/lyrics/farruko/cucaracha.html',
#               '/lyrics/farruko/lambo.html',
#               '/lyrics/farruko/mylova.html',
#               '/lyrics/farruko/bajacali.html',
#               '/lyrics/farruko/laperla.html',
#               '/lyrics/farruko/cuervos.html',
#               '/lyrics/farruko/elincomprendido.html',
#               '/lyrics/farruko/embalao.html',
#               '/lyrics/farruko/jibaro.html',
#               '/lyrics/farruko/1196017.html',
#               '/lyrics/farruko/167.html',
#               '/lyrics/farruko/baya.html',
#               '/lyrics/farruko/doblel.html',
#               '/lyrics/farruko/guerrero.html',
#               '/lyrics/farruko/amigosnuevosno.html',
#               '/lyrics/farruko/labendicion.html',
#               '/lyrics/farruko/wfm.html',
#               '/lyrics/farruko/apuntaydispara.html',
#               '/lyrics/farruko/siempresere.html',
#               '/lyrics/farruko/helicoptero.html',
#               '/lyrics/farruko/6am.html',
#               '/lyrics/farruko/alegrasmividamas.html',
#               '/lyrics/farruko/alteredcarbon.html',
#               '/lyrics/farruko/amg.html',
#               '/lyrics/farruko/amordueleremix.html',
#               '/lyrics/farruko/apagalaluz.html',
#               '/lyrics/farruko/aruba.html',
#               '/lyrics/farruko/baby.html',
#               '/lyrics/farruko/babymamaremix.html',
#               '/lyrics/farruko/bonitabebe.html',
#               '/lyrics/farruko/boomboneo.html',
#               '/lyrics/farruko/bootycall.html',
#               '/lyrics/farruko/burrosdesalitre.html',
#               '/lyrics/farruko/calor.html',
#               '/lyrics/farruko/canam.html',
#               '/lyrics/farruko/celebration.html',
#               '/lyrics/farruko/celosa.html',
#               '/lyrics/farruko/cfmgangaremix.html',
#               '/lyrics/farruko/chapichapi.html',
#               '/lyrics/farruko/chulaysexy.html',
#               '/lyrics/farruko/cikacikaremix.html',
#               '/lyrics/farruko/clavadoenunbar.html',
#               '/lyrics/farruko/comoelviento.html',
#               '/lyrics/farruko/coolant.html',
#               '/lyrics/farruko/coscuvsfarrukothe247.html',
#               '/lyrics/farruko/cositasquehaciamos.html',
#               '/lyrics/farruko/daleconto.html',
#               '/lyrics/farruko/dalequevoy.html',
#               '/lyrics/farruko/datetuguille.html',
#               '/lyrics/farruko/diabla.html',
#               '/lyrics/farruko/diablaremix.html',
#               '/lyrics/farruko/dondeestaras.html',
#               '/lyrics/farruko/elexorcista.html',
#               '/lyrics/farruko/elrelojnosedetiene.html',
#               '/lyrics/farruko/eltiempopasa.html',
#               '/lyrics/farruko/enlalenta.html',
#               '/lyrics/farruko/enlamiaremix.html',
#               '/lyrics/farruko/enamoradodeldinero.html',
#               '/lyrics/farruko/espirituguerrero.html',
#               '/lyrics/farruko/estavidasalsaversion.html',
#               '/lyrics/farruko/fantasias.html',
#               '/lyrics/farruko/fantasiasunplugged.html',
#               '/lyrics/farruko/fuego.html',
#               '/lyrics/farruko/ganas.html',
#               '/lyrics/farruko/gatasbocinasybajo.html',
#               '/lyrics/farruko/goodenergyremix.html',
#               '/lyrics/farruko/guillao.html',
#               '/lyrics/farruko/hoysientoquevuelo.html',
#               '/lyrics/farruko/huracheee.html',
#               '/lyrics/farruko/incompleto.html',
#               '/lyrics/farruko/inolvidableremix.html',
#               '/lyrics/farruko/juraste.html',
#               '/lyrics/farruko/krippykushremix.html',
#               '/lyrics/farruko/krippykushtravisscottremix.html',
#               '/lyrics/farruko/laenvidia.html',
#               '/lyrics/farruko/laformaenquememirasremix.html',
#               '/lyrics/farruko/laopinionestuya.html',
#               '/lyrics/farruko/latoxicaremix.html',
#               '/lyrics/farruko/liberace.html',
#               '/lyrics/farruko/liberaceremix.html',
#               '/lyrics/farruko/liberaceremix541833.html',
#               '/lyrics/farruko/lleca.html',
#               '/lyrics/farruko/lodeellaesfichuriar.html',
#               '/lyrics/farruko/location.html',
#               '/lyrics/farruko/locoenamorado.html',
#               '/lyrics/farruko/lonely.html',
#               '/lyrics/farruko/losr.html',
#               '/lyrics/farruko/love66.html',
#               '/lyrics/farruko/masdineromasproblemas.html',
#               '/lyrics/farruko/msqueunamigo.html',
#               '/lyrics/farruko/mayorqueyo4.html',
#               '/lyrics/farruko/medespidoremix.html',
#               '/lyrics/farruko/mehacesvolar.html',
#               '/lyrics/farruko/melevanto.html',
#               '/lyrics/farruko/mesientosolo.html',
#               '/lyrics/farruko/miformadesermamboversion.html',
#               '/lyrics/farruko/mimejorcancion.html',
#               '/lyrics/farruko/millonarioconautotune.html',
#               '/lyrics/farruko/misericordia.html',
#               '/lyrics/farruko/mordiosalas321.html',
#               '/lyrics/farruko/mordiosalas321remix.html',
#               '/lyrics/farruko/mujeriego.html',
#               '/lyrics/farruko/mundoaparte.html',
#               '/lyrics/farruko/musica.html',
#               '/lyrics/farruko/nada.html',
#               '/lyrics/farruko/nadieremix.html',
#               '/lyrics/farruko/natalyremix.html',
#               '/lyrics/farruko/nazareno.html',
#               '/lyrics/farruko/nazarenoremix.html',
#               '/lyrics/farruko/no.html',
#               '/lyrics/farruko/noentienden.html',
#               '/lyrics/farruko/nohagocoro.html',
#               '/lyrics/farruko/nohagocororemix.html',
#               '/lyrics/farruko/nolebajes.html',
#               '/lyrics/farruko/nomejuzgues.html',
#               '/lyrics/farruko/noteenamoresremix.html',
#               '/lyrics/farruko/ohmama.html',
#               '/lyrics/farruko/omg.html',
#               '/lyrics/farruko/paromperladiscoteca.html',
#               '/lyrics/farruko/pamorirsenace.html',
#               '/lyrics/farruko/pamorirsenaceremix.html',
#               '/lyrics/farruko/paredesdehielo.html',
#               '/lyrics/farruko/pasajero.html',
#               '/lyrics/farruko/patiodelacarceltangos.html',
#               '/lyrics/farruko/paz.html',
#               '/lyrics/farruko/pelea.html',
#               '/lyrics/farruko/pepasdavidguettaremix.html',
#               '/lyrics/farruko/pepasrobinschulzremix.html',
#               '/lyrics/farruko/pepastiestoremix.html',
#               '/lyrics/farruko/perdoname.html',
#               '/lyrics/farruko/perreointenso.html',
#               '/lyrics/farruko/prosperoaonuevo.html',
#               '/lyrics/farruko/prosperoanonuevoiii.html',
#               '/lyrics/farruko/purafalsedad.html',
#               '/lyrics/farruko/pure.html',
#               '/lyrics/farruko/quequieresdemi.html',
#               '/lyrics/farruko/quiremeremix.html',
#               '/lyrics/farruko/realguerreroremix.html',
#               '/lyrics/farruko/recuerdosremix.html',
#               '/lyrics/farruko/scarface.html',
#               '/lyrics/farruko/sensualinspiration.html',
#               '/lyrics/farruko/serquiensoy.html',
#               '/lyrics/farruko/siseda.html',
#               '/lyrics/farruko/situnoestas.html',
#               '/lyrics/farruko/sinti.html',
#               '/lyrics/farruko/starboyspanishversion.html',
#               '/lyrics/farruko/telometoyo.html',
#               '/lyrics/farruko/terecordare.html',
#               '/lyrics/farruko/temblorremix.html',
#               '/lyrics/farruko/tiemposremix.html',
#               '/lyrics/farruko/unpapiquelamima.html',
#               '/lyrics/farruko/viaje.html',
#               '/lyrics/farruko/vivirmivida.html',
#               '/lyrics/farruko/vuelve.html',
#               '/lyrics/farruko/watablamblam.html',
#               '/lyrics/farruko/webcamremix.html',
#               '/lyrics/farruko/welcometosanjuan.html',
#               '/lyrics/farruko/xoxa.html',
#               '/lyrics/farruko/zaranana.html',
#               '/lyrics/farruko/zero.html']})

# %% [markdown]
# Let's make sure we have enough lyrics pages to scrape.

# %%
for artist, lp in lyrics_pages.items() :
    assert(len(set(lp)) > 20)

# %%
# Let's see how long it's going to take to pull these lyrics 
# if we're waiting `5 + 10*random.random()` seconds 
for artist, links in lyrics_pages.items() : 
    print(f"For {artist} we have {len(links)}.")
    print(f"The full pull will take for this artist will take {round(len(links)*10/3600,2)} hours.")
# Out:
# For badbunny we have 195.
# The full pull will take for this artist will take 0.54 hours.
# For farruko we have 335.
# The full pull will take for this artist will take 0.93 hours.

# %% [markdown]
# ## Part 2: Pulling Lyrics
#
# Now that we have the links to our lyrics pages, let's go scrape them! Here are the steps for this part.
#
# 1. Create an empty folder in our repo called "lyrics".
# 1. Iterate over the artists in `lyrics_pages`.
# 1. Create a subfolder in lyrics with the artist's name. For instance, if the artist was Cher you'd have `lyrics/cher/` in your repo.
# 1. Iterate over the pages.
# 1. Request the page and extract the lyrics from the returned HTML file using BeautifulSoup.
# 1. Use the function below, `generate_filename_from_url`, to create a filename based on the lyrics page, then write the lyrics to a text file with that name.

# %%
def generate_filename_from_link(link) :
    
    if not link :
        return None
    
    # drop the http or https and the html
    name = link.replace("https","").replace("http","")
    name = link.replace(".html","")

    name = name.replace("/lyrics/","")
    
    # Replace useless chareacters with UNDERSCORE
    name = name.replace("://","").replace(".","_").replace("/","_")
    
    # tack on .txt
    name = name + ".txt"
    
    return(name)

# %%
# Make the lyrics folder here. If you'd like to practice your programming, add functionality 
# that checks to see if the folder exists. If it does, then use shutil.rmtree to remove it and create a new one.

if os.path.isdir("lyrics") : 
    shutil.rmtree("lyrics/")

os.mkdir("lyrics")

# %%
url_stub = "https://www.azlyrics.com" 
start = time.time()

total_pages = 0 
n_songs = 20  # song limit to extract

for artist in lyrics_pages:

    # Use this space to carry out the following steps: 
    
    # 1. Build a subfolder for the artist
    os.makedirs("lyrics/" + artist, exist_ok=True)
    PATH = "lyrics/"

    # 2. Iterate over the lyrics pages
    for url in lyrics_pages[artist][:n_songs]:
    
        # 3. Request the lyrics page. 
            # Don't forget to add a line like `time.sleep(5 + 10*random.random())`
            # to sleep after making the request
        r = requests.get(url_stub + url)
        time.sleep(5 + 10*random.random())

        # 4. Extract the title and lyrics from the page.
        #    Call 'title' tag and find lyric line. Then convert to text
        soup = BeautifulSoup(r.text,"html.parser")
        title = soup.title.text  
        lyrics = soup.find_all('div', {'class': None})[0].text

        # 5. Write out the title, two returns ('\n'), and the lyrics. Use `generate_filename_from_url`
        #    to generate the filename. 
        filename = generate_filename_from_link(url)
        filepath = PATH + artist + "/" + filename
        with open(filepath, 'w') as file:
            file.write(title + '\n\n' + lyrics)

        total_pages += 1
        print(f"File {total_pages}: {filename}")

    # Remember to pull at least 20 songs per artist. It may be fun to pull all the songs for the artist
# Out:
# File 1: badbunny_nibiennimal.txt
# File 2: badbunny_200mph.txt
# File 3: badbunny_quinteres.txt
# File 4: badbunny_caro.txt
# File 5: badbunny_tenemosquehablar.txt
# File 6: badbunny_otranocheenmiami.txt
# File 7: badbunny_serbichote.txt
# File 8: badbunny_siestuvisemosjuntos.txt
# File 9: badbunny_solodemi.txt
# File 10: badbunny_cuandoperriabas.txt
# File 11: badbunny_laromana.txt
# File 12: badbunny_comoantes.txt
# File 13: badbunny_rlndt.txt
# File 14: badbunny_estamosbien.txt
# File 15: badbunny_mia708486.txt
# File 16: badbunny_siveoatumama.txt
# File 17: badbunny_ladificil.txt
# File 18: badbunny_peroyano.txt
# File 19: badbunny_lasanta.txt
# File 20: badbunny_yoperreosola.txt
# File 21: farruko_intro.txt
# File 22: farruko_nenafichu.txt
# File 23: farruko_ulala.txt
# File 24: farruko_ellanoesfcil.txt
# File 25: farruko_casadeplaya.txt
# File 26: farruko_pormiedoalamor.txt
# File 27: farruko_webcam.txt
# File 28: farruko_escuelasuperior.txt
# File 29: farruko_gettogether.txt
# File 30: farruko_muchachitabonita.txt
# File 31: farruko_traimeatuamiga.txt
# File 32: farruko_suhijamegusta.txt
# File 33: farruko_chuleraenpote.txt
# File 34: farruko_teirabuscar.txt
# File 35: farruko_titerito.txt
# File 36: farruko_dimequehago.txt
# File 37: farruko_pikete.txt
# File 38: farruko_feeltherhythm.txt
# File 39: farruko_elnico.txt
# File 40: farruko_nopierdas.txt

# %%
print(f"Total run time was {round((time.time() - start)/3600,2)} hours.")
# Out:
# Total run time was 0.13 hours.

# %% [markdown]
# ---
#
# # Evaluation
#
# This assignment asks you to pull data by scraping www.AZLyrics.com.  After you have finished the above sections , run all the cells in this notebook. Print this to PDF and submit it, per the instructions.

# %%
# Simple word extractor from Peter Norvig: https://norvig.com/spell-correct.html
def words(text): 
    return re.findall(r'\w+', text.lower())

# %% [markdown]
# ## Checking Lyrics
#
# The output from your lyrics scrape should be stored in files located in this path from the directory:
# `/lyrics/[Artist Name]/[filename from URL]`. This code summarizes the information at a high level to help the instructor evaluate your work.

# %%
artist_folders = os.listdir("lyrics/")
artist_folders = [f for f in artist_folders if os.path.isdir("lyrics/" + f)]

for artist in artist_folders : 
    artist_files = os.listdir("lyrics/" + artist)
    artist_files = [f for f in artist_files if 'txt' in f or 'csv' in f or 'tsv' in f]

    print(f"For {artist} we have {len(artist_files)} files.")

    artist_words = []

    for f_name in artist_files : 
        with open("lyrics/" + artist + "/" + f_name) as infile : 
            artist_words.extend(words(infile.read()))

            
    print(f"For {artist} we have roughly {len(artist_words)} words, {len(set(artist_words))} are unique.")
# Out:
# For badbunny we have 20 files.
# For badbunny we have roughly 216 words, 58 are unique.
# For farruko we have 20 files.
# For farruko we have roughly 193 words, 56 are unique.
